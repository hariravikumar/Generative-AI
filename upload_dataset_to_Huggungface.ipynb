# %% [markdown]
# <a href="https://colab.research.google.com/github/hariravikumar/Generative-AI/blob/main/upload_dataset_to_Huggungface.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets huggingface_hub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 15.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 14.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# ...

# %% [markdown]
# #  Load food_notfood csv to google colab  to load to huggingface dataset

# %%
from datasets import load_dataset
dataset = load_dataset("csv", data_files='/content/food_not_food.csv')
print(dataset)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['Text', 'Label'],
#         num_rows: 500000
#     })
# })

# %%
dataset["train"][0]
# Out:
# {'Text': 'The Cookies was delicious at the restaurant.', 'Label': 'food'}

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
dataset.push_to_hub('harikrishna-ravikumar/food_notfood')
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/500 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/24.0 [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/harikrishna-ravikumar/food_notfood/commit/a43ed5c8b47e956e7ccba6290637ee6f3899ea68', commit_message='Upload dataset', commit_description='', oid='a43ed5c8b47e956e7ccba6290637ee6f3899ea68', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/harikrishna-ravikumar/food_notfood', endpoint='https://huggingface.co', repo_type='dataset', repo_id='harikrishna-ravikumar/food_notfood'), pr_revision=None, pr_num=None)
